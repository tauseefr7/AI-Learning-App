# %% [markdown]
# # Workflow of Learning App

# %% [markdown]
# ## 1. Extract the YouTube ID from a given link

# %%
from pytube import extract

urls = [
            'https://www.youtube.com/watch?v=MoqtsYLGCC4&t=505s&pp=ygULcnVzdCBweXRob24%3D',
            'http://www.youtube.com/embed/SA2iWivDJiE',
            'http://www.youtube.com/4380tg8h430hir',
            'https://www.youtube.com/watch?v=358hg580gh9fh05-t240'
]

for url in urls:
    video_id = extract.video_id(url)
    print(video_id)
# Out:
# MoqtsYLGCC4
# SA2iWivDJiE
# 4380tg8h430
# 358hg580gh9

# %% [markdown]
# ## 2. Extract & transform video captions

# %%
from youtube_transcript_api import YouTubeTranscriptApi
video_id = "MoqtsYLGCC4"
transcript = YouTubeTranscriptApi.get_transcript(video_id)
transcript
# Out:
# [{'text': 'rust is quickly making a name for itself',
#   'start': 0.199,
#   'duration': 5.12},
#  {'text': 'as a speedy and approachable programming',
#   'start': 2.84,
#   'duration': 4.519},
#  {'text': "language now you've been bothering me",
#   'start': 5.319,
#   'duration': 3.841},
#  {'text': 'about doing a rust video for a while now',
#   'start': 7.359,
#   'duration': 4.841},
#  {'text': 'so you win this video is my initial take',
#   'start': 9.16,
#   'duration': 5.32},
#  {'text': 'on Rust and I might just do more content',
#   'start': 12.2,
#   'duration': 4.72},
#  {'text': 'about it in the future rust has a pretty',
#   'start': 14.48,
#   'duration': 5.0},
#  {'text': 'unique approach to type safety memory',
#   'start': 16.92,
#   'duration': 4.76},
#  {'text': 'management and exception handling and',
#   'start': 19.48,
#   'duration': 3.799},
#  {'text': 'that makes it a Powerhouse for', 'start': 21.68, 'duration': 3.88},
#  {'text': 'performance critical applications there',
#   'start': 23.279,
#   'duration': 4.08},
#  {'text': 'are quite a few similarities between',
#   'start': 25.56,
#   'duration': 4.039},
#  {'text': 'Python and rust syntax and you can even',
#   'start': 27.359,
#   'duration': 4.4},
#  {'text': 'bind rust to python modules and benefit',
#   'start': 29.599,
#   'duration': 4.8},
#  {'text': "from high performance all no it's a",
#   'start': 31.759,
#   'duration': 4.841},
#  {'text': 'great language for pythonistas to pick',
#   'start': 34.399,
#   'duration': 4.16},
#  {'text': "up I'm going to show you some of the",
#   'start': 36.6,
#   'duration': 3.88},
#  {'text': 'cool features that rust brings to the',
#   'start': 38.559,
#   'duration': 4.48},
#  {'text': 'table today and how they differ from',
#   'start': 40.48,
#   'duration': 4.88},
#  {'text': 'python but before we start I have',
#   'start': 43.039,
#   'duration': 4.401},
#  {'text': 'something for you if you want to learn',
#   'start': 45.36,
#   'duration': 4.359},
#  {'text': 'how to detect problems in your code',
#   'start': 47.44,
#   'duration': 5.04},
#  {'text': 'faster check out my free code diagnosis',
#   'start': 49.719,
#   'duration': 4.84},
#  {'text': 'Workshop this is a 30 minutes a video',
#   'start': 52.48,
#   'duration': 3.879},
#  {'text': 'that teaches you a three Factor',
#   'start': 54.559,
#   'duration': 4.041},
#  {'text': 'framework to look at code and detect',
#   'start': 56.359,
#   'duration': 4.121},
#  {'text': 'problems faster in the work Workshop I',
#   'start': 58.6,
#   'duration': 3.759},
#  {'text': 'show you several examples of how to do',
#   'start': 60.48,
#   'duration': 5.4},
#  {'text': 'that using existing libraries go to ir.',
#   'start': 62.359,
#   'duration': 5.841},
#  {'text': 'go/ diagnosis to get access for free the',
#   'start': 65.88,
#   'duration': 4.279},
#  {'text': 'link is also in description of this',
#   'start': 68.2,
#   'duration': 5.08},
#  {'text': "video and now let's dive into rust I'm",
#   'start': 70.159,
#   'duration': 5.0},
#  {'text': 'going to start with something really',
#   'start': 73.28,
#   'duration': 4.479},
#  {'text': 'basic which is obviously the hello world',
#   'start': 75.159,
#   'duration': 5.121},
#  {'text': 'program now in Python the hello world',
#   'start': 77.759,
#   'duration': 5.161},
#  {'text': "program is extremely simple it's just a",
#   'start': 80.28,
#   'duration': 4.96},
#  {'text': 'single line of code a print line writing',
#   'start': 82.92,
#   'duration': 5.159},
#  {'text': 'hello world and well you probably know',
#   'start': 85.24,
#   'duration': 4.44},
#  {'text': 'this if you watch this channel so if I',
#   'start': 88.079,
#   'duration': 3.561},
#  {'text': "run this then obviously it's going to",
#   'start': 89.68,
#   'duration': 5.079},
#  {'text': 'print hello world in Rust it looks',
#   'start': 91.64,
#   'duration': 5.799},
#  {'text': 'slightly different we have a main',
#   'start': 94.759,
#   'duration': 5.201},
#  {'text': "function that's what the FN keyword is",
#   'start': 97.439,
#   'duration': 4.441},
#  {'text': 'and within it we have a print line',
#   'start': 99.96,
#   'duration': 4.159},
#  {'text': 'statement that also prints hello world',
#   'start': 101.88,
#   'duration': 4.36},
#  {'text': "now in Python it's typically a good idea",
#   'start': 104.119,
#   'duration': 4.841},
#  {'text': 'to not write lines of code directly in',
#   'start': 106.24,
#   'duration': 4.479},
#  {'text': 'the script like this but use a main',
#   'start': 108.96,
#   'duration': 3.96},
#  {'text': 'function so instead of doing this you',
#   'start': 110.719,
#   'duration': 4.881},
#  {'text': 'would have a main function and if you',
#   'start': 112.92,
#   'duration': 4.44},
#  {'text': "want to be neat then it's going to",
#   'start': 115.6,
#   'duration': 4.08},
#  {'text': "return type nonone because it's not",
#   'start': 117.36,
#   'duration': 3.719},
#  {'text': 'going going to return the result and',
#   'start': 119.68,
#   'duration': 4.039},
#  {'text': 'then we add a part of the script so that',
#   'start': 121.079,
#   'duration': 4.161},
#  {'text': "if you run the script directly then it's",
#   'start': 123.719,
#   'duration': 3.961},
#  {'text': 'going to call the main function so when',
#   'start': 125.24,
#   'duration': 4.32},
#  {'text': 'we run it like this we get exactly the',
#   'start': 127.68,
#   'duration': 3.32},
#  {'text': "same result but there's a bit more",
#   'start': 129.56,
#   'duration': 3.92},
#  {'text': 'boilerplate code and that also showcases',
#   'start': 131.0,
#   'duration': 5.0},
#  {'text': 'a big difference between Python and rust',
#   'start': 133.48,
#   'duration': 6.16},
#  {'text': 'where python is extremely flexible you',
#   'start': 136.0,
#   'duration': 5.48},
#  {'text': 'still need some guard rails as a',
#   'start': 139.64,
#   'duration': 5.48},
#  {'text': 'developer to develop properly in Python',
#   'start': 141.48,
#   'duration': 5.399},
#  {'text': 'and what I mean by that is doing things',
#   'start': 145.12,
#   'duration': 4.24},
#  {'text': 'like this where you put it in a main',
#   'start': 146.879,
#   'duration': 5.241},
#  {'text': 'function to not pollute the global scope',
#   'start': 149.36,
#   'duration': 5.239},
#  {'text': "or you're adding your return type",
#   'start': 152.12,
#   'duration': 4.199},
#  {'text': "annotation so that's clear what a",
#   'start': 154.599,
#   'duration': 5.161},
#  {'text': 'function returns or not so python offers',
#   'start': 156.319,
#   'duration': 5.601},
#  {'text': 'that freedom rust is a stricter language',
#   'start': 159.76,
#   'duration': 3.68},
#  {'text': "you can't really see that clearly in",
#   'start': 161.92,
#   'duration': 3.08},
#  {'text': "this particular example but I'll show",
#   'start': 163.44,
#   'duration': 4.079},
#  {'text': 'you more examples later in the video now',
#   'start': 165.0,
#   'duration': 4.519},
#  {'text': 'with python we can simply run the code',
#   'start': 167.519,
#   'duration': 4.0},
#  {'text': "but with rust we can't directly run the",
#   'start': 169.519,
#   'duration': 3.921},
#  {'text': 'code we need to compile it first and in',
#   'start': 171.519,
#   'duration': 3.44},
#  {'text': 'order to do that you of course need to',
#   'start': 173.44,
#   'duration': 2.96},
#  {'text': 'make sure you install rust on your',
#   'start': 174.959,
#   'duration': 3.441},
#  {'text': 'machine after you install rust here on',
#   'start': 176.4,
#   'duration': 3.559},
#  {'text': "my Mac I've done that by using The",
#   'start': 178.4,
#   'duration': 3.839},
#  {'text': 'Homebrew package manager then you have',
#   'start': 179.959,
#   'duration': 4.92},
#  {'text': "the rust compile command so what I'm",
#   'start': 182.239,
#   'duration': 4.601},
#  {'text': 'going to do is go into the rust folder',
#   'start': 184.879,
#   'duration': 3.92},
#  {'text': 'where I have my rust examples and then I',
#   'start': 186.84,
#   'duration': 4.479},
#  {'text': 'can call compile rust compile and then',
#   'start': 188.799,
#   'duration': 4.44},
#  {'text': "we're going to compile the hello world",
#   'start': 191.319,
#   'duration': 5.441},
#  {'text': "program so now it's compiled and this",
#   'start': 193.239,
#   'duration': 6.401},
#  {'text': 'has actually created an executable hello',
#   'start': 196.76,
#   'duration': 5.08},
#  {'text': "world that's what you see here so I can",
#   'start': 199.64,
#   'duration': 4.76},
#  {'text': 'now run this simply by typing hello',
#   'start': 201.84,
#   'duration': 4.24},
#  {'text': "world and now it's going to run the",
#   'start': 204.4,
#   'duration': 3.08},
#  {'text': "program so it's a bit more involved than",
#   'start': 206.08,
#   'duration': 2.879},
#  {'text': 'simply running a python script you need',
#   'start': 207.48,
#   'duration': 3.16},
#  {'text': 'to compile it first and then you have an',
#   'start': 208.959,
#   'duration': 3.92},
#  {'text': 'executable so what are some of the other',
#   'start': 210.64,
#   'duration': 4.0},
#  {'text': 'differences in Python we print something',
#   'start': 212.879,
#   'duration': 4.08},
#  {'text': 'by call the print function in Rust we',
#   'start': 214.64,
#   'duration': 4.2},
#  {'text': 'call Print line but you see there is an',
#   'start': 216.959,
#   'duration': 3.92},
#  {'text': 'exclamation mark behind it what does',
#   'start': 218.84,
#   'duration': 4.44},
#  {'text': 'that mean exactly well an exclamation',
#   'start': 220.879,
#   'duration': 5.08},
#  {'text': "mark means it's a macro macros are not",
#   'start': 223.28,
#   'duration': 3.92},
#  {'text': 'something that you might know from the',
#   'start': 225.959,
#   'duration': 3.241},
#  {'text': "python world but if you've done some",
#   'start': 227.2,
#   'duration': 4.679},
#  {'text': 'programming in c then you know that it',
#   'start': 229.2,
#   'duration': 5.28},
#  {'text': 'also has macros and macros are basically',
#   'start': 231.879,
#   'duration': 5.121},
#  {'text': "something that's executed at compile",
#   'start': 234.48,
#   'duration': 4.72},
#  {'text': 'time and they generally expand into New',
#   'start': 237.0,
#   'duration': 3.68},
#  {'text': 'pieces of code that then need to be',
#   'start': 239.2,
#   'duration': 3.64},
#  {'text': 'further processed by the compiler and',
#   'start': 240.68,
#   'duration': 4.44},
#  {'text': "there's a few reasons why macros can be",
#   'start': 242.84,
#   'duration': 3.84},
#  {'text': 'handy for example to avoid code',
#   'start': 245.12,
#   'duration': 3.92},
#  {'text': 'duplication but they can also help in',
#   'start': 246.68,
#   'duration': 4.68},
#  {'text': 'Rust if you have so-called vartic',
#   'start': 249.04,
#   'duration': 4.32},
#  {'text': 'interfaces and what I mean by that is',
#   'start': 251.36,
#   'duration': 3.76},
#  {'text': 'that you can have a function in Rust',
#   'start': 253.36,
#   'duration': 4.719},
#  {'text': 'that has a variable number of arguments',
#   'start': 255.12,
#   'duration': 5.04},
#  {'text': "functions in Ross don't support that but",
#   'start': 258.079,
#   'duration': 4.641},
#  {'text': 'macros do print line is an example of',
#   'start': 260.16,
#   'duration': 4.08},
#  {'text': "where that's useful because this macro",
#   'start': 262.72,
#   'duration': 3.32},
#  {'text': 'can take any number of arguments',
#   'start': 264.24,
#   'duration': 3.679},
#  {'text': 'depending on the format of the string',
#   'start': 266.04,
#   'duration': 3.68},
#  {'text': "now there's a few other key differences",
#   'start': 267.919,
#   'duration': 4.081},
#  {'text': 'between rust and python so one thing',
#   'start': 269.72,
#   'duration': 4.199},
#  {'text': "we've seen is that python is interpreted",
#   'start': 272.0,
#   'duration': 3.52},
#  {'text': 'so you can run the scripts directly',
#   'start': 273.919,
#   'duration': 3.881},
#  {'text': 'versus rust which is compiled and that',
#   'start': 275.52,
#   'duration': 4.0},
#  {'text': 'also means that the performance is very',
#   'start': 277.8,
#   'duration': 3.64},
#  {'text': 'different between Python and rust now',
#   'start': 279.52,
#   'duration': 4.28},
#  {'text': 'because rust is compiled it can really',
#   'start': 281.44,
#   'duration': 4.28},
#  {'text': 'optimize the code for the executable so',
#   'start': 283.8,
#   'duration': 5.0},
#  {'text': "it's really optimized for performance",
#   'start': 285.72,
#   'duration': 6.12},
#  {'text': 'whereas python is interpreted can be',
#   'start': 288.8,
#   'duration': 5.48},
#  {'text': "very Dynamic very flexible so it's going",
#   'start': 291.84,
#   'duration': 4.4},
#  {'text': 'to be slower when you run a Python',
#   'start': 294.28,
#   'duration': 3.639},
#  {'text': "program there's also a big difference in",
#   'start': 296.24,
#   'duration': 4.48},
#  {'text': 'typing python has dynamic types you can',
#   'start': 297.919,
#   'duration': 4.921},
#  {'text': 'omit them if you want or add them and',
#   'start': 300.72,
#   'duration': 3.759},
#  {'text': "python it doesn't really care just",
#   'start': 302.84,
#   'duration': 3.639},
#  {'text': 'throws away the types when it starts',
#   'start': 304.479,
#   'duration': 5.841},
#  {'text': 'interpreting the script rust is static',
#   'start': 306.479,
#   'duration': 6.321},
#  {'text': 'strongly typed so rust has way more',
#   'start': 310.32,
#   'duration': 4.76},
#  {'text': 'restrictions and way more rules about',
#   'start': 312.8,
#   'duration': 5.519},
#  {'text': 'how to use type than python so rust is',
#   'start': 315.08,
#   'duration': 5.08},
#  {'text': 'much more particular about types than',
#   'start': 318.319,
#   'duration': 3.32},
#  {'text': 'Python and it also makes sense because',
#   'start': 320.16,
#   'duration': 3.68},
#  {'text': "often at compile time you'd like to know",
#   'start': 321.639,
#   'duration': 4.4},
#  {'text': 'what the types are of things so you can',
#   'start': 323.84,
#   'duration': 4.88},
#  {'text': 'properly address the correct amount of',
#   'start': 326.039,
#   'duration': 4.121},
#  {'text': "memory and things like like that there's",
#   'start': 328.72,
#   'duration': 3.36},
#  {'text': 'also a difference into how Python and',
#   'start': 330.16,
#   'duration': 4.44},
#  {'text': 'rust manage memory in general python has',
#   'start': 332.08,
#   'duration': 6.04},
#  {'text': 'automatic garbage collection rust uses',
#   'start': 334.6,
#   'duration': 6.36},
#  {'text': 'another memory management model based on',
#   'start': 338.12,
#   'duration': 5.0},
#  {'text': "ownership so it's a bit different there",
#   'start': 340.96,
#   'duration': 3.64},
#  {'text': 'are differences in concurrency', 'start': 343.12, 'duration': 3.12},
#  {'text': 'multi-threading python has the global',
#   'start': 344.6,
#   'duration': 4.52},
#  {'text': "interpreter lock Russ doesn't have that",
#   'start': 346.24,
#   'duration': 4.92},
#  {'text': 'error handling is also a really big',
#   'start': 349.12,
#   'duration': 4.12},
#  {'text': 'difference between the two so python has',
#   'start': 351.16,
#   'duration': 4.319},
#  {'text': 'exceptions now I have talked about',
#   'start': 353.24,
#   'duration': 4.799},
#  {'text': 'monatic error handling in earlier videos',
#   'start': 355.479,
#   'duration': 4.481},
#  {'text': 'on the channel but this is actually what',
#   'start': 358.039,
#   'duration': 4.361},
#  {'text': 'rust Builds on so instead of having',
#   'start': 359.96,
#   'duration': 5.0},
#  {'text': 'exceptions it has result and option',
#   'start': 362.4,
#   'duration': 4.4},
#  {'text': "types and I'll show those to you in a",
#   'start': 364.96,
#   'duration': 4.12},
#  {'text': 'minute syntax of python and rust is',
#   'start': 366.8,
#   'duration': 3.76},
#  {'text': 'obviously different though there is also',
#   'start': 369.08,
#   'duration': 3.679},
#  {'text': "some overlap Python's syntax is very",
#   'start': 370.56,
#   'duration': 3.6},
#  {'text': 'clean and concise with a lot of',
#   'start': 372.759,
#   'duration': 4.16},
#  {'text': 'flexibility whereas rust is more strict',
#   'start': 374.16,
#   'duration': 4.56},
#  {'text': 'but also more explicit and it makes it a',
#   'start': 376.919,
#   'duration': 3.84},
#  {'text': 'bit more for both now putting all these',
#   'start': 378.72,
#   'duration': 3.879},
#  {'text': 'things together means that in general',
#   'start': 380.759,
#   'duration': 3.681},
#  {'text': 'python is going to be more beginner',
#   'start': 382.599,
#   'duration': 3.72},
#  {'text': "friendly there's just less things to",
#   'start': 384.44,
#   'duration': 3.64},
#  {'text': 'worry about Russ definitely has a',
#   'start': 386.319,
#   'duration': 3.32},
#  {'text': "steeper learning curve but if you're",
#   'start': 388.08,
#   'duration': 3.239},
#  {'text': 'developing more complex applications',
#   'start': 389.639,
#   'duration': 4.4},
#  {'text': 'that can actually be a huge win because',
#   'start': 391.319,
#   'duration': 5.0},
#  {'text': 'it forces you as a developer to do',
#   'start': 394.039,
#   'duration': 4.241},
#  {'text': 'things properly and of course in the end',
#   'start': 396.319,
#   'duration': 3.121},
#  {'text': "it's going to result in a more", 'start': 398.28, 'duration': 2.96},
#  {'text': "performance program and there's more",
#   'start': 399.44,
#   'duration': 3.8},
#  {'text': 'differences between Python and rust',
#   'start': 401.24,
#   'duration': 4.56},
#  {'text': 'python has support for both a functional',
#   'start': 403.24,
#   'duration': 4.28},
#  {'text': 'style of programming and an', 'start': 405.8, 'duration': 4.399},
#  {'text': 'objectoriented style of programming rust',
#   'start': 407.52,
#   'duration': 5.239},
#  {'text': 'is mostly functional though it has some',
#   'start': 410.199,
#   'duration': 4.801},
#  {'text': 'aspects of objectoriented programming',
#   'start': 412.759,
#   'duration': 3.601},
#  {'text': 'and you can also see that in the way',
#   'start': 415.0,
#   'duration': 4.039},
#  {'text': 'that rust adopts more functional style',
#   'start': 416.36,
#   'duration': 4.399},
#  {'text': 'program programming Concepts such as',
#   'start': 419.039,
#   'duration': 4.321},
#  {'text': 'railroad oriented programming where',
#   'start': 420.759,
#   'duration': 4.28},
#  {'text': 'instead of using exceptions like in',
#   'start': 423.36,
#   'duration': 4.32},
#  {'text': 'Python you use a result type that can be',
#   'start': 425.039,
#   'duration': 5.241},
#  {'text': 'either on a happy path or on an error',
#   'start': 427.68,
#   'duration': 5.0},
#  {'text': 'path rust also has lots of chaining',
#   'start': 430.28,
#   'duration': 5.56},
#  {'text': 'style methods like map filter folding',
#   'start': 432.68,
#   'duration': 5.239},
#  {'text': "that's also why rust has the option type",
#   'start': 435.84,
#   'duration': 4.44},
#  {'text': 'where you can either represent a value',
#   'start': 437.919,
#   'duration': 4.84},
#  {'text': 'or none if there is no value for example',
#   'start': 440.28,
#   'duration': 4.599},
#  {'text': 'due to a method failure python in',
#   'start': 442.759,
#   'duration': 4.201},
#  {'text': 'general is more suited to the dock',
#   'start': 444.879,
#   'duration': 4.561},
#  {'text': 'typing style of programming where you',
#   'start': 446.96,
#   'duration': 4.32},
#  {'text': "don't really care what the type is of",
#   'start': 449.44,
#   'duration': 4.68},
#  {'text': 'objects and if some data is missing or',
#   'start': 451.28,
#   'duration': 4.24},
#  {'text': 'there is some other issue it just',
#   'start': 454.12,
#   'duration': 3.919},
#  {'text': 'crashes with an error now this does make',
#   'start': 455.52,
#   'duration': 4.519},
#  {'text': 'it a lot easier to get started writing',
#   'start': 458.039,
#   'duration': 4.361},
#  {'text': 'your code in Python but also means that',
#   'start': 460.039,
#   'duration': 4.84},
#  {'text': 'sometimes you can encounter bugs and',
#   'start': 462.4,
#   'duration': 4.32},
#  {'text': 'issues that are hard to track because',
#   'start': 464.879,
#   'duration': 4.521},
#  {'text': "you just don't have a clear view of what",
#   'start': 466.72,
#   'duration': 4.68},
#  {'text': 'the types are of things if you develop',
#   'start': 469.4,
#   'duration': 4.079},
#  {'text': 'in Rust most of these issues already',
#   'start': 471.4,
#   'duration': 4.359},
#  {'text': 'going to come forward at the compile',
#   'start': 473.479,
#   'duration': 4.521},
#  {'text': "stage so you won't encounter that error",
#   'start': 475.759,
#   'duration': 4.081},
#  {'text': 'when running the program but but when',
#   'start': 478.0,
#   'duration': 3.96},
#  {'text': 'compiling the program which means that',
#   'start': 479.84,
#   'duration': 4.72},
#  {'text': "as a developer you're going to see those",
#   'start': 481.96,
#   'duration': 4.16},
#  {'text': 'problems sooner and you can fix them',
#   'start': 484.56,
#   'duration': 3.56},
#  {'text': 'sooner if you already know python then',
#   'start': 486.12,
#   'duration': 4.199},
#  {'text': 'it can be helpful to learn rust to',
#   'start': 488.12,
#   'duration': 4.44},
#  {'text': 'because there are modules such as Pio 3',
#   'start': 490.319,
#   'duration': 5.761},
#  {'text': 'and CFI that you can use to bridge rust',
#   'start': 492.56,
#   'duration': 5.039},
#  {'text': 'with python this means that you can',
#   'start': 496.08,
#   'duration': 4.0},
#  {'text': 'write performance critical code in Rust',
#   'start': 497.599,
#   'duration': 4.241},
#  {'text': 'and then call that code from within a',
#   'start': 500.08,
#   'duration': 3.64},
#  {'text': 'python script which is kind of The Best',
#   'start': 501.84,
#   'duration': 4.24},
#  {'text': 'of Both Worlds now mention that rust is',
#   'start': 503.72,
#   'duration': 4.36},
#  {'text': 'more of a functional style language and',
#   'start': 506.08,
#   'duration': 4.239},
#  {'text': 'python offers both both object-oriented',
#   'start': 508.08,
#   'duration': 4.879},
#  {'text': 'programming and functional programming',
#   'start': 510.319,
#   'duration': 4.921},
#  {'text': "so let's take a closer look at how you",
#   'start': 512.959,
#   'duration': 4.96},
#  {'text': 'would solve a typical objectoriented',
#   'start': 515.24,
#   'duration': 5.599},
#  {'text': 'programming problem with rust so in',
#   'start': 517.919,
#   'duration': 5.0},
#  {'text': 'Python if we need to represent objects',
#   'start': 520.839,
#   'duration': 4.521},
#  {'text': 'of some sort then we can use classes',
#   'start': 522.919,
#   'duration': 3.881},
#  {'text': 'here we have a very simple example of',
#   'start': 525.36,
#   'duration': 3.72},
#  {'text': 'that a class user which has a name and',
#   'start': 526.8,
#   'duration': 3.719},
#  {'text': 'an email address the email address is',
#   'start': 529.08,
#   'duration': 3.56},
#  {'text': 'constructed from the name and then we',
#   'start': 530.519,
#   'duration': 4.601},
#  {'text': 'have a method that uses the data in the',
#   'start': 532.64,
#   'duration': 4.72},
#  {'text': 'object in this case the email address to',
#   'start': 535.12,
#   'duration': 5.08},
#  {'text': 'perform some task very basic basic in',
#   'start': 537.36,
#   'duration': 5.479},
#  {'text': 'Rust this will look very different so',
#   'start': 540.2,
#   'duration': 5.0},
#  {'text': 'here I have basically the same program',
#   'start': 542.839,
#   'duration': 4.761},
#  {'text': "but written in Rust so let's break down",
#   'start': 545.2,
#   'duration': 4.52},
#  {'text': 'what is happening exactly here so we',
#   'start': 547.6,
#   'duration': 4.12},
#  {'text': 'have again a main function which is the',
#   'start': 549.72,
#   'duration': 4.799},
#  {'text': 'entry point of the application and we',
#   'start': 551.72,
#   'duration': 5.08},
#  {'text': 'have here something called a struct and',
#   'start': 554.519,
#   'duration': 4.401},
#  {'text': 'an imple and this shows a big difference',
#   'start': 556.8,
#   'duration': 4.479},
#  {'text': "between Python and rust so rust doesn't",
#   'start': 558.92,
#   'duration': 4.919},
#  {'text': 'have classes but what rust does have is',
#   'start': 561.279,
#   'duration': 5.081},
#  {'text': 'a struct which is basically a grouping',
#   'start': 563.839,
#   'duration': 5.961},
#  {'text': 'of data so we have here a user struct',
#   'start': 566.36,
#   'duration': 5.719},
#  {'text': 'that has a name and an email and then',
#   'start': 569.8,
#   'duration': 4.88},
#  {'text': 'what we can do is Define a grouping of',
#   'start': 572.079,
#   'duration': 5.361},
#  {'text': 'functions which is an imple of that',
#   'start': 574.68,
#   'duration': 4.599},
#  {'text': 'particular struct and there we can',
#   'start': 577.44,
#   'duration': 4.079},
#  {'text': 'Define functions for example here we',
#   'start': 579.279,
#   'duration': 5.201},
#  {'text': 'have a new function that gets a name and',
#   'start': 581.519,
#   'duration': 5.081},
#  {'text': 'returns a user so the return type',
#   'start': 584.48,
#   'duration': 4.479},
#  {'text': 'annotation in Python looks very similar',
#   'start': 586.6,
#   'duration': 5.32},
#  {'text': "here it's we also write it like this and",
#   'start': 588.959,
#   'duration': 6.161},
#  {'text': 'what this does is that it returns a user',
#   'start': 591.92,
#   'duration': 6.359},
#  {'text': 'with a name and an email again we see',
#   'start': 595.12,
#   'duration': 5.24},
#  {'text': 'the use of a macro here that does',
#   'start': 598.279,
#   'duration': 3.641},
#  {'text': 'formatting and the reason this is a',
#   'start': 600.36,
#   'duration': 4.2},
#  {'text': 'macro is again because it can have any',
#   'start': 601.92,
#   'duration': 4.919},
#  {'text': 'number of arguments depending on how you',
#   'start': 604.56,
#   'duration': 4.24},
#  {'text': 'want to format the string formatting is',
#   'start': 606.839,
#   'duration': 3.401},
#  {'text': 'done by supplying these kinds of',
#   'start': 608.8,
#   'duration': 3.52},
#  {'text': "handlebars where we're going to replace",
#   'start': 610.24,
#   'duration': 3.8},
#  {'text': 'this by the value in variable here',
#   'start': 612.32,
#   'duration': 3.959},
#  {'text': 'similar to The Format function in Python',
#   'start': 614.04,
#   'duration': 3.68},
#  {'text': 'by the way and then what happens here in',
#   'start': 616.279,
#   'duration': 3.041},
#  {'text': 'the main function is that we Define a',
#   'start': 617.72,
#   'duration': 4.72},
#  {'text': 'user variable and we assign it the value',
#   'start': 619.32,
#   'duration': 6.48},
#  {'text': "that this new function returns and it's",
#   'start': 622.44,
#   'duration': 6.639},
#  {'text': 'part of the user implementation and then',
#   'start': 625.8,
#   'duration': 5.92},
#  {'text': 'finally we print some information namely',
#   'start': 629.079,
#   'duration': 4.561},
#  {'text': 'the username and the user email which is',
#   'start': 631.72,
#   'duration': 3.2},
#  {'text': 'part of the user object because we',
#   'start': 633.64,
#   'duration': 3.24},
#  {'text': 'Define it as a struct here at the top of',
#   'start': 634.92,
#   'duration': 3.52},
#  {'text': "the file there's a couple of other",
#   'start': 636.88,
#   'duration': 3.28},
#  {'text': 'differences here as well so you see this',
#   'start': 638.44,
#   'duration': 4.68},
#  {'text': "and sign that means it's a reference so",
#   'start': 640.16,
#   'duration': 4.6},
#  {'text': 'that means that internally the value',
#   'start': 643.12,
#   'duration': 3.36},
#  {'text': "that's pass to this new function is",
#   'start': 644.76,
#   'duration': 3.72},
#  {'text': 'going to be the same memory location',
#   'start': 646.48,
#   'duration': 4.08},
#  {'text': 'within the function body as outside of',
#   'start': 648.48,
#   'duration': 4.28},
#  {'text': 'the function body it refers to the same',
#   'start': 650.56,
#   'duration': 4.279},
#  {'text': 'data you also see that we have a type',
#   'start': 652.76,
#   'duration': 4.12},
#  {'text': 'string with capital letter and a',
#   'start': 654.839,
#   'duration': 4.281},
#  {'text': 'lowercase s Str so these are also',
#   'start': 656.88,
#   'duration': 3.84},
#  {'text': 'slightly different and it has to do with',
#   'start': 659.12,
#   'duration': 5.04},
#  {'text': 'mutability so in Python by default',
#   'start': 660.72,
#   'duration': 5.28},
#  {'text': "variables can be changed they're",
#   'start': 664.16,
#   'duration': 4.0},
#  {'text': 'variables right uh you can assign them a',
#   'start': 666.0,
#   'duration': 3.839},
#  {'text': "new value you don't have to do anything",
#   'start': 668.16,
#   'duration': 3.64},
#  {'text': 'special in fact in Python there is no',
#   'start': 669.839,
#   'duration': 3.961},
#  {'text': 'easy way to indicate that something is a',
#   'start': 671.8,
#   'duration': 3.88},
#  {'text': 'constant you can change anything you',
#   'start': 673.8,
#   'duration': 4.8},
#  {'text': "like it's very flexible in Rust it's the",
#   'start': 675.68,
#   'duration': 5.56},
#  {'text': 'other way around by default everything',
#   'start': 678.6,
#   'duration': 5.679},
#  {'text': 'is constant everything is not mutable',
#   'start': 681.24,
#   'duration': 4.76},
#  {'text': "that means I can't do something like",
#   'start': 684.279,
#   'duration': 5.281},
#  {'text': 'user do uh email equals', 'start': 686.0, 'duration': 6.079},
#  {'text': 'uh something else right because the user',
#   'start': 689.56,
#   'duration': 4.92},
#  {'text': "is not mutable I can't do that let me",
#   'start': 692.079,
#   'duration': 4.121},
#  {'text': 'show you by running the actual program',
#   'start': 694.48,
#   'duration': 4.24},
#  {'text': 'so if I compile the original version',
#   'start': 696.2,
#   'duration': 5.48},
#  {'text': 'like so and then let me run this then',
#   'start': 698.72,
#   'duration': 4.64},
#  {'text': 'well this is what we get and if I now',
#   'start': 701.68,
#   'duration': 4.76},
#  {'text': 'try to change the', 'start': 703.36, 'duration': 3.08},
#  {'text': "username like so and then let's compile",
#   'start': 706.959,
#   'duration': 5.201},
#  {'text': 'again you see that now we get an error',
#   'start': 710.16,
#   'duration': 3.679},
#  {'text': "we can't assign to use. name because",
#   'start': 712.16,
#   'duration': 4.239},
#  {'text': 'user is not declared as mutable things',
#   'start': 713.839,
#   'duration': 4.56},
#  {'text': 'not being mutable is also a typical',
#   'start': 716.399,
#   'duration': 3.601},
#  {'text': "functional thing thing to do it's also",
#   'start': 718.399,
#   'duration': 3.281},
#  {'text': 'it also works like that in a purely',
#   'start': 720.0,
#   'duration': 4.399},
#  {'text': 'functional language like has for example',
#   'start': 721.68,
#   'duration': 4.24},
#  {'text': 'if you want things to be mutable you',
#   'start': 724.399,
#   'duration': 3.801},
#  {'text': 'have to be explicit about it and you can',
#   'start': 725.92,
#   'duration': 3.919},
#  {'text': "do that it's actually very simple just",
#   'start': 728.2,
#   'duration': 4.72},
#  {'text': 'by writing mut mute in front of the',
#   'start': 729.839,
#   'duration': 5.081},
#  {'text': "variable name so now that I've changed",
#   'start': 732.92,
#   'duration': 5.44},
#  {'text': 'this and let me then compile use. RS',
#   'start': 734.92,
#   'duration': 4.84},
#  {'text': 'again you see that now it compiles',
#   'start': 738.36,
#   'duration': 4.0},
#  {'text': 'without any issue and then I can run it',
#   'start': 739.76,
#   'duration': 4.04},
#  {'text': 'and now we have change the name it still',
#   'start': 742.36,
#   'duration': 2.96},
#  {'text': 'prints the same thing because I changed',
#   'start': 743.8,
#   'duration': 4.32},
#  {'text': 'the name after this print line and email',
#   'start': 745.32,
#   'duration': 4.92},
#  {'text': 'and email is only changed when we create',
#   'start': 748.12,
#   'duration': 4.159},
#  {'text': "the object so it doesn't have any impact",
#   'start': 750.24,
#   'duration': 3.719},
#  {'text': 'here but it does change the name maybe I',
#   'start': 752.279,
#   'duration': 3.961},
#  {'text': 'should move this print line right here',
#   'start': 753.959,
#   'duration': 3.641},
#  {'text': 'so that we can actually show that it',
#   'start': 756.24,
#   'duration': 4.52},
#  {'text': 'changed the name so let me compile this',
#   'start': 757.6,
#   'duration': 5.56},
#  {'text': 'again and then we run it and then you',
#   'start': 760.76,
#   'duration': 4.48},
#  {'text': "see Hello iron codes email didn't change",
#   'start': 763.16,
#   'duration': 3.84},
#  {'text': 'because that happens in the uh', 'start': 765.24, 'duration': 4.12},
#  {'text': 'initialization part of the struct like',
#   'start': 767.0,
#   'duration': 4.72},
#  {'text': 'also mentioned rust has a real Road',
#   'start': 769.36,
#   'duration': 4.599},
#  {'text': 'oriented programming kind of Style',
#   'start': 771.72,
#   'duration': 4.679},
#  {'text': 'versus python that uses exception and',
#   'start': 773.959,
#   'duration': 4.041},
#  {'text': 'that means it deals differently with',
#   'start': 776.399,
#   'duration': 3.721},
#  {'text': "errors also Ross doesn't have a non-",
#   'start': 778.0,
#   'duration': 3.8},
#  {'text': 'type like python so you never have to be',
#   'start': 780.12,
#   'duration': 3.44},
#  {'text': "afraid that your variable doesn't have a",
#   'start': 781.8,
#   'duration': 3.719},
#  {'text': 'value and the way that you deal instead',
#   'start': 783.56,
#   'duration': 3.56},
#  {'text': 'with those cases is that is that you',
#   'start': 785.519,
#   'duration': 3.801},
#  {'text': "have an option type so here I've added",
#   'start': 787.12,
#   'duration': 4.519},
#  {'text': 'two functions one of them is get user',
#   'start': 789.32,
#   'duration': 5.16},
#  {'text': 'option that returns not just a user but',
#   'start': 791.639,
#   'duration': 6.281},
#  {'text': 'an optional user it gets a name and then',
#   'start': 794.48,
#   'duration': 6.0},
#  {'text': "if the name equals Aron then I'm going",
#   'start': 797.92,
#   'duration': 4.919},
#  {'text': "to return a user if it doesn't it's",
#   'start': 800.48,
#   'duration': 4.44},
#  {'text': 'going to return nonone this may look',
#   'start': 802.839,
#   'duration': 4.401},
#  {'text': "like the python nonone value but it's",
#   'start': 804.92,
#   'duration': 4.2},
#  {'text': "actually not a value it's part of option",
#   'start': 807.24,
#   'duration': 3.599},
#  {'text': 'type so it works slightly differently',
#   'start': 809.12,
#   'duration': 3.2},
#  {'text': 'let me show you what I mean in the main',
#   'start': 810.839,
#   'duration': 3.921},
#  {'text': "function I've now created a user option",
#   'start': 812.32,
#   'duration': 4.84},
#  {'text': "that calls this function and then I'm",
#   'start': 814.76,
#   'duration': 5.04},
#  {'text': 'going to print the name of that',
#   'start': 817.16,
#   'duration': 4.72},
#  {'text': 'particular user what happens if I',
#   'start': 819.8,
#   'duration': 3.92},
#  {'text': "compile this is that it's going to",
#   'start': 821.88,
#   'duration': 4.68},
#  {'text': "complain that name doesn't exist on the",
#   'start': 823.72,
#   'duration': 4.84},
#  {'text': 'option type so I have to handle the',
#   'start': 826.56,
#   'duration': 4.399},
#  {'text': 'option type somehow so instead of doing',
#   'start': 828.56,
#   'duration': 5.519},
#  {'text': 'this what I need to do is add a match',
#   'start': 830.959,
#   'duration': 4.921},
#  {'text': 'you already see that GitHub copal does',
#   'start': 834.079,
#   'duration': 4.2},
#  {'text': 'this for me so this is similar to',
#   'start': 835.88,
#   'duration': 4.8},
#  {'text': "Python's structural pattern matching so",
#   'start': 838.279,
#   'duration': 5.24},
#  {'text': "a matching user option if it's some user",
#   'start': 840.68,
#   'duration': 5.719},
#  {'text': 'then I can call Print line and none then',
#   'start': 843.519,
#   'duration': 6.0},
#  {'text': "I do this so we can't really do anything",
#   'start': 846.399,
#   'duration': 5.521},
#  {'text': 'specific with a nonv value we just use',
#   'start': 849.519,
#   'duration': 5.0},
#  {'text': 'it in matching to take different actions',
#   'start': 851.92,
#   'duration': 5.88},
#  {'text': 'in our program so when I compile this',
#   'start': 854.519,
#   'duration': 5.32},
#  {'text': 'well we get a warning because get user',
#   'start': 857.8,
#   'duration': 4.279},
#  {'text': "result is currently not used because I'm",
#   'start': 859.839,
#   'duration': 3.761},
#  {'text': 'going to show you that in a minute but',
#   'start': 862.079,
#   'duration': 3.841},
#  {'text': 'the program is going to run without any',
#   'start': 863.6,
#   'duration': 4.12},
#  {'text': "issue now so that's what you can do with",
#   'start': 865.92,
#   'duration': 4.159},
#  {'text': 'the option type Sly you can also use the',
#   'start': 867.72,
#   'duration': 4.16},
#  {'text': 'result type which is an example of',
#   'start': 870.079,
#   'duration': 3.76},
#  {'text': 'monatic error handling so this is',
#   'start': 871.88,
#   'duration': 3.959},
#  {'text': 'specifically for handling errors so in',
#   'start': 873.839,
#   'duration': 4.92},
#  {'text': 'this case if name equals iron then the',
#   'start': 875.839,
#   'duration': 5.44},
#  {'text': "value is going to be okay we're still on",
#   'start': 878.759,
#   'duration': 4.241},
#  {'text': "the good side of things and then it's",
#   'start': 881.279,
#   'duration': 4.161},
#  {'text': "going to return a user else it's going",
#   'start': 883.0,
#   'duration': 4.399},
#  {'text': "to return an error and that's of type",
#   'start': 885.44,
#   'duration': 6.56},
#  {'text': 'string so we can also add a user result',
#   'start': 887.399,
#   'duration': 6.921},
#  {'text': 'and then similarly to how we match the',
#   'start': 892.0,
#   'duration': 5.12},
#  {'text': 'optional type we can also match the uh',
#   'start': 894.32,
#   'duration': 4.879},
#  {'text': 'result type by looking either at the',
#   'start': 897.12,
#   'duration': 3.8},
#  {'text': 'okay side of things or at the error side',
#   'start': 899.199,
#   'duration': 3.961},
#  {'text': 'of things so let me compile this one',
#   'start': 900.92,
#   'duration': 5.039},
#  {'text': 'more time and then if we run the code',
#   'start': 903.16,
#   'duration': 4.52},
#  {'text': 'then we get this', 'start': 905.959, 'duration': 6.8},
#  {'text': 'but if I now change this to something',
#   'start': 907.68,
#   'duration': 5.079},
#  {'text': 'else I compile this again and then I run',
#   'start': 914.72,
#   'duration': 5.679},
#  {'text': "this you see user not found and that's",
#   'start': 917.8,
#   'duration': 4.68},
#  {'text': 'because we went over to the arrow path',
#   'start': 920.399,
#   'duration': 4.281},
#  {'text': 'here so option and results look very',
#   'start': 922.48,
#   'duration': 4.52},
#  {'text': 'similar when should you use which so the',
#   'start': 924.68,
#   'duration': 4.399},
#  {'text': 'option type is typically used when the',
#   'start': 927.0,
#   'duration': 4.639},
#  {'text': 'value of a certain computation may be',
#   'start': 929.079,
#   'duration': 4.081},
#  {'text': 'absent for example if you have a',
#   'start': 931.639,
#   'duration': 3.0},
#  {'text': 'function that looks for an item in a',
#   'start': 933.16,
#   'duration': 3.28},
#  {'text': "dictionary and the item doesn't exist",
#   'start': 934.639,
#   'duration': 3.281},
#  {'text': 'then you can use the option type to',
#   'start': 936.44,
#   'duration': 3.879},
#  {'text': 'indicate that there is no value use the',
#   'start': 937.92,
#   'duration': 3.919},
#  {'text': "result type when it's important to make",
#   'start': 940.319,
#   'duration': 3.841},
#  {'text': 'a distinction between an okay state of',
#   'start': 941.839,
#   'duration': 4.281},
#  {'text': 'the program and an error state of the',
#   'start': 944.16,
#   'duration': 3.56},
#  {'text': 'program for example if your function',
#   'start': 946.12,
#   'duration': 4.0},
#  {'text': "reads a file but the file doesn't exist",
#   'start': 947.72,
#   'duration': 4.2},
#  {'text': "that's more clearly an error state that",
#   'start': 950.12,
#   'duration': 3.76},
#  {'text': 'you need to handle in both cases though',
#   'start': 951.92,
#   'duration': 3.52},
#  {'text': 'you can use the match statement to',
#   'start': 953.88,
#   'duration': 3.16},
#  {'text': 'handle each of the different cases',
#   'start': 955.44,
#   'duration': 3.6},
#  {'text': "whether you're using an option type or",
#   'start': 957.04,
#   'duration': 4.12},
#  {'text': 'result type a final thing that I want to',
#   'start': 959.04,
#   'duration': 4.239},
#  {'text': 'show you in Rost is trades and this is',
#   'start': 961.16,
#   'duration': 4.84},
#  {'text': 'similar to how you would Define ABCs or',
#   'start': 963.279,
#   'duration': 5.161},
#  {'text': 'protocols in Python so here I have an',
#   'start': 966.0,
#   'duration': 4.68},
#  {'text': 'example of an ABC and Abstract Base',
#   'start': 968.44,
#   'duration': 4.56},
#  {'text': 'Class called iot device it has a couple',
#   'start': 970.68,
#   'duration': 4.279},
#  {'text': 'of abstract methods like connecting',
#   'start': 973.0,
#   'duration': 3.759},
#  {'text': 'disconnecting sending a message',
#   'start': 974.959,
#   'duration': 3.601},
#  {'text': 'receiving a message and so on and then',
#   'start': 976.759,
#   'duration': 4.44},
#  {'text': "we have a class light that's a subass of",
#   'start': 978.56,
#   'duration': 5.199},
#  {'text': 'the iot device that implements these',
#   'start': 981.199,
#   'duration': 4.08},
#  {'text': 'methods on top of that we have a',
#   'start': 983.759,
#   'duration': 3.0},
#  {'text': 'connection class that handles the',
#   'start': 985.279,
#   'duration': 3.24},
#  {'text': 'connection so this is not a real',
#   'start': 986.759,
#   'duration': 4.32},
#  {'text': 'connection this is mostly a simulation',
#   'start': 988.519,
#   'duration': 6.161},
#  {'text': 'and then at the bottom we have an enom',
#   'start': 991.079,
#   'duration': 5.961},
#  {'text': 'connection status that is being used by',
#   'start': 994.68,
#   'duration': 3.959},
#  {'text': 'these and then we create a connection we',
#   'start': 997.04,
#   'duration': 3.479},
#  {'text': 'have some testing code so the light',
#   'start': 998.639,
#   'duration': 5.081},
#  {'text': 'class is a subass of iot device and by',
#   'start': 1000.519,
#   'duration': 5.041},
#  {'text': 'doing this this allows us to make sure',
#   'start': 1003.72,
#   'duration': 4.119},
#  {'text': 'that light implements all the necessary',
#   'start': 1005.56,
#   'duration': 4.16},
#  {'text': 'methods and Russ you can do something',
#   'start': 1007.839,
#   'duration': 3.68},
#  {'text': "similar it's not called a protocol or an",
#   'start': 1009.72,
#   'duration': 3.559},
#  {'text': "ABC but it's called a trait and that's",
#   'start': 1011.519,
#   'duration': 3.88},
#  {'text': 'what you see here so we have a trait iot',
#   'start': 1013.279,
#   'duration': 4.281},
#  {'text': 'device that has functions connect',
#   'start': 1015.399,
#   'duration': 4.281},
#  {'text': 'disconnect send and receiving and you',
#   'start': 1017.56,
#   'duration': 4.6},
#  {'text': 'also see that it receives a mutable self',
#   'start': 1019.68,
#   'duration': 4.0},
#  {'text': 'that means that this is going to change',
#   'start': 1022.16,
#   'duration': 3.96},
#  {'text': 'the self object a tradeit is really a',
#   'start': 1023.68,
#   'duration': 4.639},
#  {'text': "specification of an interface what's",
#   'start': 1026.12,
#   'duration': 3.679},
#  {'text': 'interesting is that this is not',
#   'start': 1028.319,
#   'duration': 3.6},
#  {'text': 'associated with type you have to do that',
#   'start': 1029.799,
#   'duration': 5.441},
#  {'text': 'explicitly so if we have a light struct',
#   'start': 1031.919,
#   'duration': 6.841},
#  {'text': 'which has a connection value then you',
#   'start': 1035.24,
#   'duration': 5.959},
#  {'text': 'can provide an implementation just like',
#   'start': 1038.76,
#   'duration': 5.4},
#  {'text': 'we did for the user of this particular',
#   'start': 1041.199,
#   'duration': 6.0},
#  {'text': 'trait Internet of Things device for the',
#   'start': 1044.16,
#   'duration': 5.12},
#  {'text': "light type and that's where you specify",
#   'start': 1047.199,
#   'duration': 4.081},
#  {'text': 'the various functions like connecting',
#   'start': 1049.28,
#   'duration': 4.32},
#  {'text': 'disconnecting sending and receiving and',
#   'start': 1051.28,
#   'duration': 4.08},
#  {'text': 'next to implementing the trade you can',
#   'start': 1053.6,
#   'duration': 3.4},
#  {'text': 'also just like we did for the user',
#   'start': 1055.36,
#   'duration': 3.52},
#  {'text': 'struct in this example you can also',
#   'start': 1057.0,
#   'duration': 3.64},
#  {'text': 'provide an implementation for light that',
#   'start': 1058.88,
#   'duration': 3.48},
#  {'text': 'supplies additional functions like the',
#   'start': 1060.64,
#   'duration': 3.88},
#  {'text': 'new function that creates a light value',
#   'start': 1062.36,
#   'duration': 4.0},
#  {'text': 'with a particular connection and then',
#   'start': 1064.52,
#   'duration': 3.399},
#  {'text': 'again we have a main function where we',
#   'start': 1066.36,
#   'duration': 3.24},
#  {'text': 'have light which needs to be mutable',
#   'start': 1067.919,
#   'duration': 3.801},
#  {'text': 'because we change the light object by',
#   'start': 1069.6,
#   'duration': 3.959},
#  {'text': 'connecting and disconnecting from it and',
#   'start': 1071.72,
#   'duration': 4.04},
#  {'text': 'then we print some status information so',
#   'start': 1073.559,
#   'duration': 5.201},
#  {'text': "if I run this let's compile first first",
#   'start': 1075.76,
#   'duration': 4.48},
#  {'text': 'you see we get some warnings there is',
#   'start': 1078.76,
#   'duration': 2.919},
#  {'text': "some dead code because there's a final",
#   'start': 1080.24,
#   'duration': 2.84},
#  {'text': 'thing that I want to show you in a',
#   'start': 1081.679,
#   'duration': 3.721},
#  {'text': 'minute but if I then run', 'start': 1083.08, 'duration': 4.959},
#  {'text': "this then this is what we get so that's",
#   'start': 1085.4,
#   'duration': 4.84},
#  {'text': 'an example of how you could introduce',
#   'start': 1088.039,
#   'duration': 4.481},
#  {'text': 'abstraction in a rust program by using',
#   'start': 1090.24,
#   'duration': 3.84},
#  {'text': 'traits and like I said the main',
#   'start': 1092.52,
#   'duration': 3.12},
#  {'text': 'difference between using something like',
#   'start': 1094.08,
#   'duration': 4.68},
#  {'text': 'an ABC in python versus a trade and rust',
#   'start': 1095.64,
#   'duration': 5.64},
#  {'text': 'is that there is no inheritance involved',
#   'start': 1098.76,
#   'duration': 4.96},
#  {'text': "here it's really implementing trades for",
#   'start': 1101.28,
#   'duration': 4.279},
#  {'text': 'a particular type and you have to do',
#   'start': 1103.72,
#   'duration': 3.8},
#  {'text': "that explicitly like we're doing here",
#   'start': 1105.559,
#   'duration': 3.761},
#  {'text': 'for the light Tye but what happens if',
#   'start': 1107.52,
#   'duration': 3.6},
#  {'text': 'you have other types of Internet of',
#   'start': 1109.32,
#   'duration': 4.04},
#  {'text': 'Things devices as well like maybe a',
#   'start': 1111.12,
#   'duration': 5.24},
#  {'text': 'switch and a router and other things do',
#   'start': 1113.36,
#   'duration': 4.72},
#  {'text': 'you need to then copy paste this code',
#   'start': 1116.36,
#   'duration': 3.559},
#  {'text': "well no and that's where you can use",
#   'start': 1118.08,
#   'duration': 4.36},
#  {'text': 'macros again here you see an example of',
#   'start': 1119.919,
#   'duration': 5.081},
#  {'text': 'specifying a macro this is how you do',
#   'start': 1122.44,
#   'duration': 5.96},
#  {'text': 'that that takes a certain type and then',
#   'start': 1125.0,
#   'duration': 7.36},
#  {'text': 'implements iot device for that type and',
#   'start': 1128.4,
#   'duration': 5.72},
#  {'text': 'then it simply creates the connect',
#   'start': 1132.36,
#   'duration': 4.24},
#  {'text': 'disconnect send and receive methods and',
#   'start': 1134.12,
#   'duration': 4.88},
#  {'text': 'now you can use this macro instead of',
#   'start': 1136.6,
#   'duration': 4.64},
#  {'text': 'having to write the implementation the',
#   'start': 1139.0,
#   'duration': 4.0},
#  {'text': 'trade implementation for this particular',
#   'start': 1141.24,
#   'duration': 4.28},
#  {'text': 'type so instead of now writing', 'start': 1143.0, 'duration': 5.32},
#  {'text': 'this we can comment this out which is',
#   'start': 1145.52,
#   'duration': 4.8},
#  {'text': 'done by double slashes by the way and',
#   'start': 1148.32,
#   'duration': 4.96},
#  {'text': "then we can simply do this and that's",
#   'start': 1150.32,
#   'duration': 5.04},
#  {'text': 'also going to implement those trades by',
#   'start': 1153.28,
#   'duration': 3.32},
#  {'text': 'the way if you like these types of',
#   'start': 1155.36,
#   'duration': 2.679},
#  {'text': "discussions and you'd like to stay",
#   'start': 1156.6,
#   'duration': 2.92},
#  {'text': "informed on what's happening in the",
#   'start': 1158.039,
#   'duration': 4.561},
#  {'text': 'software industry including rust then',
#   'start': 1159.52,
#   'duration': 4.92},
#  {'text': 'make sure you subscribe to my free',
#   'start': 1162.6,
#   'duration': 3.68},
#  {'text': 'Weekly Newsletter by using the link',
#   'start': 1164.44,
#   'duration': 4.16},
#  {'text': 'below so I hope this has given you a',
#   'start': 1166.28,
#   'duration': 5.12},
#  {'text': 'idea of what rust is and how it works',
#   'start': 1168.6,
#   'duration': 4.88},
#  {'text': "how it's different from python so in",
#   'start': 1171.4,
#   'duration': 3.399},
#  {'text': "summary some of the things that we've",
#   'start': 1173.48,
#   'duration': 3.24},
#  {'text': "seen with rust is that it's very",
#   'start': 1174.799,
#   'duration': 4.321},
#  {'text': "powerful it's fast high performance it's",
#   'start': 1176.72,
#   'duration': 5.16},
#  {'text': 'type safe and it is verose more verbose',
#   'start': 1179.12,
#   'duration': 4.52},
#  {'text': "than python but it's still relatively",
#   'start': 1181.88,
#   'duration': 4.919},
#  {'text': "easy to write it's strict and I kind of",
#   'start': 1183.64,
#   'duration': 4.8},
#  {'text': 'like it so does this mean we should all',
#   'start': 1186.799,
#   'duration': 3.841},
#  {'text': 'throw python out of the window well no',
#   'start': 1188.44,
#   'duration': 4.76},
#  {'text': 'python is still a very flexible powerful',
#   'start': 1190.64,
#   'duration': 4.32},
#  {'text': "language that's very easy to start",
#   'start': 1193.2,
#   'duration': 3.719},
#  {'text': 'coding in it has Dynamic typing and',
#   'start': 1194.96,
#   'duration': 3.64},
#  {'text': 'allows you to do lots of things',
#   'start': 1196.919,
#   'duration': 2.88},
#  {'text': "especially if you don't really care",
#   'start': 1198.6,
#   'duration': 3.0},
#  {'text': 'about performance so much just like',
#   'start': 1199.799,
#   'duration': 4.321},
#  {'text': 'python Rost has a growing ecosystem of',
#   'start': 1201.6,
#   'duration': 4.28},
#  {'text': 'libraries that you can use and if you',
#   'start': 1204.12,
#   'duration': 3.559},
#  {'text': 'create a rust binding then you can',
#   'start': 1205.88,
#   'duration': 4.159},
#  {'text': 'actually call Rost code from python',
#   'start': 1207.679,
#   'duration': 4.801},
#  {'text': 'which sort of gives you the best of both',
#   'start': 1210.039,
#   'duration': 4.76},
#  {'text': 'worlds so this video has been out of my',
#   'start': 1212.48,
#   'duration': 4.079},
#  {'text': "comfort zone I don't have tons of",
#   'start': 1214.799,
#   'duration': 3.681},
#  {'text': 'experience with rust I still enjoyed',
#   'start': 1216.559,
#   'duration': 3.281},
#  {'text': 'playing around with the language though',
#   'start': 1218.48,
#   'duration': 3.199},
#  {'text': "if you'd like me to do more content",
#   'start': 1219.84,
#   'duration': 3.52},
#  {'text': 'about rust just let me know in the',
#   'start': 1221.679,
#   'duration': 3.681},
#  {'text': 'comments below regardless of what',
#   'start': 1223.36,
#   'duration': 3.559},
#  {'text': 'programming language you use whether',
#   'start': 1225.36,
#   'duration': 5.0},
#  {'text': "that's rust by or something else solving",
#   'start': 1226.919,
#   'duration': 5.561},
#  {'text': 'complex programming problems is easier',
#   'start': 1230.36,
#   'duration': 4.559},
#  {'text': 'if you adopt first principle thinking if',
#   'start': 1232.48,
#   'duration': 4.76},
#  {'text': 'you want to learn how to do that watch',
#   'start': 1234.919,
#   'duration': 5.201},
#  {'text': 'this video next thanks for watching and',
#   'start': 1237.24,
#   'duration': 5.76},
#  {'text': 'see you soon', 'start': 1240.12, 'duration': 2.88}]

# %%
transcript = " ".join([item["text"] for item in transcript])
transcript
# Out:
# "rust is quickly making a name for itself as a speedy and approachable programming language now you've been bothering me about doing a rust video for a while now so you win this video is my initial take on Rust and I might just do more content about it in the future rust has a pretty unique approach to type safety memory management and exception handling and that makes it a Powerhouse for performance critical applications there are quite a few similarities between Python and rust syntax and you can even bind rust to python modules and benefit from high performance all no it's a great language for pythonistas to pick up I'm going to show you some of the cool features that rust brings to the table today and how they differ from python but before we start I have something for you if you want to learn how to detect problems in your code faster check out my free code diagnosis Workshop this is a 30 minutes a video that teaches you a three Factor framework to look at code and detect problems faster in the work Workshop I show you several examples of how to do that using existing libraries go to ir. go/ diagnosis to get access for free the link is also in description of this video and now let's dive into rust I'm going to start with something really basic which is obviously the hello world program now in Python the hello world program is extremely simple it's just a single line of code a print line writing hello world and well you probably know this if you watch this channel so if I run this then obviously it's going to print hello world in Rust it looks slightly different we have a main function that's what the FN keyword is and within it we have a print line statement that also prints hello world now in Python it's typically a good idea to not write lines of code directly in the script like this but use a main function so instead of doing this you would have a main function and if you want to be neat then it's going to return type nonone because it's not going going to return the result and then we add a part of the script so that if you run the script directly then it's going to call the main function so when we run it like this we get exactly the same result but there's a bit more boilerplate code and that also showcases a big difference between Python and rust where python is extremely flexible you still need some guard rails as a developer to develop properly in Python and what I mean by that is doing things like this where you put it in a main function to not pollute the global scope or you're adding your return type annotation so that's clear what a function returns or not so python offers that freedom rust is a stricter language you can't really see that clearly in this particular example but I'll show you more examples later in the video now with python we can simply run the code but with rust we can't directly run the code we need to compile it first and in order to do that you of course need to make sure you install rust on your machine after you install rust here on my Mac I've done that by using The Homebrew package manager then you have the rust compile command so what I'm going to do is go into the rust folder where I have my rust examples and then I can call compile rust compile and then we're going to compile the hello world program so now it's compiled and this has actually created an executable hello world that's what you see here so I can now run this simply by typing hello world and now it's going to run the program so it's a bit more involved than simply running a python script you need to compile it first and then you have an executable so what are some of the other differences in Python we print something by call the print function in Rust we call Print line but you see there is an exclamation mark behind it what does that mean exactly well an exclamation mark means it's a macro macros are not something that you might know from the python world but if you've done some programming in c then you know that it al ...

# %% [markdown]
# ## 3. Feed video captions into LLM (OpenAI)

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts.chat import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate
from langchain.chains import LLMChain

#########################################
OPENAI_API_KEY = "sk-xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"
#########################################


template = f"""
    You are an assistant designed to create questions based on any given text. For each text segment you receive, your task is to generate 5 unique questions. Each question should be paired with 4 possible answers: one correct answer and three incorrect answers.

    To ensure clarity and ease of processing, format your response to resemble a Python list of lists.

    Your response should be structured as follows:

    1. An outer list containing 5 inner lists.
    2. Each inner list should represent a question and its answers, containing exactly 5 strings in this order:
       - The generated question.
       - The correct answer.
       - The first incorrect answer.
       - The second incorrect answer.
       - The third incorrect answer.

    Your response should look like this:
    [
        ["Generated Question 1", "Correct Answer 1", "Incorrect Answer 1.1", "Incorrect Answer 1.2", "Incorrect Answer 1.3"],
        ["Generated Question 2", "Correct Answer 2", "Incorrect Answer 2.1", "Incorrect Answer 2.2", "Incorrect Answer 2.3"],
        ...
    ]

    It is essential to follow this format as it is optimized for subsequent Python processing.
"""

system_message_prompt = SystemMessagePromptTemplate.from_template(template)
human_message_prompt = HumanMessagePromptTemplate.from_template("{text}")
chat_prompt = ChatPromptTemplate.from_messages(
    [system_message_prompt, human_message_prompt]
)
chain = LLMChain(
    llm=ChatOpenAI(openai_api_key=OPENAI_API_KEY),
    prompt=chat_prompt,
)
quiz_data = chain.run(transcript)
print(type(quiz_data))
print(quiz_data)
# Out:
# <class 'str'>
# [
#     ["What type of programming language is Rust known for being?", "Speedy and approachable", "Slow and challenging", "Complex and slow", "Simple and difficult"],
#     ["What does Rust use for error handling instead of exceptions?", "Result and option types", "Exceptions and errors", "None and value types", "Errors and exceptions"],
#     ["How does Rust handle memory management compared to Python?", "Based on ownership", "Using automatic garbage collection", "Does not handle memory", "Based on exceptions"],
#     ["What is a major difference in how Python and Rust handle typing?", "Python is dynamic, Rust is static", "Python is static, Rust is dynamic", "Both are dynamic", "Both are static"],
#     ["What feature in Rust helps with code expansion at compile time?", "Macros", "Functions", "Classes", "Variables"]
# ]

# %% [markdown]
# ## 4. Transform output

# %%
import ast

quiz_data_clean = ast.literal_eval(quiz_data)
print(type(quiz_data_clean))
print(quiz_data_clean)
# Out:
# <class 'list'>
# [['What type of programming language is Rust known for being?', 'Speedy and approachable', 'Slow and challenging', 'Complex and slow', 'Simple and difficult'], ['What does Rust use for error handling instead of exceptions?', 'Result and option types', 'Exceptions and errors', 'None and value types', 'Errors and exceptions'], ['How does Rust handle memory management compared to Python?', 'Based on ownership', 'Using automatic garbage collection', 'Does not handle memory', 'Based on exceptions'], ['What is a major difference in how Python and Rust handle typing?', 'Python is dynamic, Rust is static', 'Python is static, Rust is dynamic', 'Both are dynamic', 'Both are static'], ['What feature in Rust helps with code expansion at compile time?', 'Macros', 'Functions', 'Classes', 'Variables']]
